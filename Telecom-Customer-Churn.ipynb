# %% [markdown]
# ## Customer Churn Prediction for TELECOM Company
# #### Lots of companies face the issue of losing their customers, so as a part of customer retention program we need to predict customer churn before they decide to leave.<br/>In order to do that we would use this dataset and create a Classification model to predict that whether a customer would churn or not.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns', 50)
df=pd.read_csv('Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %% [markdown]
# #### The dataset has 7043 records with 21 different features including customer id and churn

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# #### Most of the columns are object type, but for developing model we need numeric values and some label encoding as well, so now we will change datatype of some columns and change string values to numeric values by encoding them.

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
def changeColumnsToString(df):
    columnsNames=['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
    for col in columnsNames:
        df[col]=df[col].astype('str').str.replace('Yes','1').replace('No','0').replace('No internet service','0').replace('No phone service',0)

changeColumnsToString(df)

df['SeniorCitizen']=df['SeniorCitizen'].astype(bool)
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female          False       1          0       1            0
# 1  5575-GNVDE    Male          False       0          0      34            1
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0             0             DSL              0            1                0
# 1             0             DSL              1            0                1
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0           0           0               0  Month-to-month                1
# 1           0           0               0        One year                0
#
#       PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0  Electronic check           29.85         29.85     0
# 1      Mailed check           56.95       1889.50     0

# %% [markdown]
# #### There are some categorical values which can be encoded as numbers, so we will take a look at unique values present as categories and convert these fields as category and encode them.

# %%
print("Payment methods: ",df.PaymentMethod.unique())
print("Contract types: ",df.Contract.unique())
print("Gender: ",df.gender.unique())
print("Senior Citizen: ",df.SeniorCitizen.unique())
print("Internet Service Types: ",df.InternetService.unique())
# Out:
# Payment methods:  ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Contract types:  ['Month-to-month' 'One year' 'Two year']
# Gender:  ['Female' 'Male']
# Senior Citizen:  [False  True]
# Internet Service Types:  ['DSL' 'Fiber optic' 'No']

# %%
df['gender']=df['gender'].astype('category')
df['PaymentMethod']=df['PaymentMethod'].astype('category')
df['Contract']=df['Contract'].astype('category')
df['SeniorCitizen']=df['SeniorCitizen'].astype('category')
df['InternetService']=df['InternetService'].astype('category')
df.dtypes
# Out:
# customerID            object
# gender              category
# SeniorCitizen       category
# Partner               object
# Dependents            object
# tenure                 int64
# PhoneService          object
# MultipleLines         object
# InternetService     category
# OnlineSecurity        object
# OnlineBackup          object
# DeviceProtection      object
# TechSupport           object
# StreamingTV           object
# StreamingMovies       object
# Contract            category
# PaperlessBilling      object
# PaymentMethod       category
# MonthlyCharges       float64
# TotalCharges         float64
# Churn                 object
# dtype: object

# %% [markdown]
# #### Here we have encoded fields with numbers by pandas build-in get_dummies method, and using that method we need to give prefix for new fields which will be generated.
# #### This method will generate new fields with prefix and category name as column name and 0 or 1 will be their value.
# #### As we can see below, we got all the new fields with values as 0 or 1.

# %%
dfPaymentDummies = pd.get_dummies(df['PaymentMethod'], prefix = 'payment')
dfContractDummies = pd.get_dummies(df['Contract'], prefix = 'contract')
dfGenderDummies = pd.get_dummies(df['gender'], prefix = 'gender')
dfSeniorCitizenDummies = pd.get_dummies(df['SeniorCitizen'], prefix = 'SC')
dfInternetServiceDummies = pd.get_dummies(df['InternetService'], prefix = 'IS')

print(dfPaymentDummies.head(3))
print(dfContractDummies.head(3))
print(dfGenderDummies.head(3))
print(dfSeniorCitizenDummies.head(3))
print(dfInternetServiceDummies.head(3))
# Out:
#    payment_Bank transfer (automatic)  payment_Credit card (automatic)  \
# 0                                  0                                0
# 1                                  0                                0
# 2                                  0                                0
#
#    payment_Electronic check  payment_Mailed check
# 0                         1                     0
# 1                         0                     1
# 2                         0                     1
#    contract_Month-to-month  contract_One year  contract_Two year
# 0                        1                  0                  0
# 1                        0                  1                  0
# 2                        1                  0                  0
#    gender_Female  gender_Male
# 0              1            0
# 1              0            1
# 2              0            1
#    SC_False  SC_True
# 0         1        0
# 1         1        0
# 2         1        0
#    IS_DSL  IS_Fiber optic  IS_No
# 0       1               0      0
# 1       1               0      0
# 2       1               0      0

# %% [markdown]
# #### Now we have new dataframes by label encoding, so we will concat them with our existing dataframe, but before that we will remove category fields as we don't need them right!

# %%
df.drop(['gender','PaymentMethod','Contract','SeniorCitizen','InternetService'], axis=1, inplace=True)

df = pd.concat([df, dfPaymentDummies], axis=1)
df = pd.concat([df, dfContractDummies], axis=1)
df = pd.concat([df, dfGenderDummies], axis=1)
df = pd.concat([df, dfSeniorCitizenDummies], axis=1)
df = pd.concat([df, dfInternetServiceDummies], axis=1)
df.head(2)
# Out:
#    customerID Partner Dependents  tenure PhoneService MultipleLines  \
# 0  7590-VHVEG       1          0       1            0             0
# 1  5575-GNVDE       0          0      34            1             0
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0              0            1                0           0           0
# 1              1            0                1           0           0
#
#   StreamingMovies PaperlessBilling  MonthlyCharges  TotalCharges Churn  \
# 0               0                1           29.85         29.85     0
# 1               0                0           56.95       1889.50     0
#
#    payment_Bank transfer (automatic)  payment_Credit card (automatic)  \
# 0                                  0                                0
# 1                                  0                                0
#
#    payment_Electronic check  payment_Mailed check  contract_Month-to-month  \
# 0                         1                     0                        1
# 1                         0                     1                        0
#
#    contract_One year  contract_Two year  gender_Female  gender_Male  SC_False  \
# 0                  0                  0              1            0         1
# 1                  1                  0              0            1         1
#
#    SC_True  IS_DSL  IS_Fiber optic  IS_No
# 0        0       1               0      0
# 1        0       1               0      0

# %% [markdown]
# #### For a bit of simplicity, we'll rename some column names

# %%
df.columns = ['customerID', 'Partner', 'Dependents', 'tenure', 'PhoneService',
       'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling',
       'MonthlyCharges', 'TotalCharges', 'Churn',
       'payment_Bank_transfer_auto', 'payment_Credit_card_auto',
       'payment_Electronic_check', 'payment_Mailed_check',
       'contract_Month_to_month', 'contract_One_year', 'contract_Two_year',
       'gender_Female', 'gender_Male', 'SC_False', 'SC_True', 'IS_DSL',
       'IS_Fiber_optic', 'IS_No']

# %% [markdown]
# #### We'll convert all fields to number type in dataframe for our model.
# #### Here we are wrapping up data preparation phase.

# %%
numericColumns=np.array(['Partner', 'Dependents', 'tenure', 'PhoneService',
       'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling',
       'MonthlyCharges', 'TotalCharges', 'Churn',
       'payment_Bank_transfer_auto', 'payment_Credit_card_auto',
       'payment_Electronic_check', 'payment_Mailed_check',
       'contract_Month_to_month', 'contract_One_year', 'contract_Two_year',
       'gender_Female', 'gender_Male', 'SC_False', 'SC_True', 'IS_DSL',
       'IS_Fiber_optic', 'IS_No'])

for columnName in numericColumns:
    df[columnName]=pd.to_numeric(df[columnName],errors='coerce')
df.dtypes
# Out:
# customerID                     object
# Partner                         int64
# Dependents                      int64
# tenure                          int64
# PhoneService                    int64
# MultipleLines                   int64
# OnlineSecurity                  int64
# OnlineBackup                    int64
# DeviceProtection                int64
# TechSupport                     int64
# StreamingTV                     int64
# StreamingMovies                 int64
# PaperlessBilling                int64
# MonthlyCharges                float64
# TotalCharges                  float64
# Churn                           int64
# payment_Bank_transfer_auto      uint8
# payment_Credit_card_auto        uint8
# payment_Electronic_check        uint8
# payment_Mailed_check            uint8
# contract_Month_to_month         uint8
# contract_One_year               uint8
# contract_Two_year               uint8
# gender_Female                   uint8
# gender_Male                     uint8
# SC_False                        uint8
# SC_True                         uint8
# IS_DSL                          uint8
# IS_Fiber_optic                  uint8
# IS_No                           uint8
# dtype: object

# %% [markdown]
# #### We'll save our model data to new csv file without customerID, as we won't be using that in our model development.

# %%
modelData = df.loc[:, df.columns != 'customerID']
modelData.to_csv('modelData.csv')

# %% [markdown]
# ### <b>Model Development</b>
# #### After reading our model data, we'll take our training and target data in numpy arrays

# %%
modelData=pd.read_csv('modelData.csv')

modelData[modelData==np.inf]=np.nan
modelData.fillna(modelData.mean(), inplace=True)

x=np.asarray(modelData.loc[:,modelData.columns != 'Churn'])
y=np.asarray(modelData['Churn'])

print(x[:2])
print(y[:2])
# Out:
# [[0.0000e+00 1.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   1.0000e+00 2.9850e+01 2.9850e+01 0.0000e+00 0.0000e+00 1.0000e+00
#   0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00
#   1.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00]
#  [1.0000e+00 0.0000e+00 0.0000e+00 3.4000e+01 1.0000e+00 0.0000e+00
#   1.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 5.6950e+01 1.8895e+03 0.0000e+00 0.0000e+00 0.0000e+00
#   1.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00 1.0000e+00
#   1.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00]]
# [0 0]

# %% [markdown]
# #### Here we'll normalize our data by using sklearn's StandardScaler

# %%
from sklearn import preprocessing
x = preprocessing.StandardScaler().fit(x).transform(x)
x[0:2]
# Out:
# array([[-1.7318049 ,  1.03453023, -0.65401193, -1.27744458, -3.05401039,
#         -0.85417615, -0.63393298,  1.3782406 , -0.72396752, -0.63943864,
#         -0.79013171, -0.79607014,  0.8297975 , -1.16032292, -0.99497138,
#         -0.5298852 , -0.52504733,  1.40641839, -0.54480692,  0.90418382,
#         -0.51424938, -0.56297505,  1.00955867, -1.00955867,  0.43991649,
#         -0.43991649,  1.38171215, -0.88565976, -0.52592737],
#        [-1.73131305, -0.96662231, -0.65401193,  0.06632742,  0.32743831,
#         -0.85417615,  1.57745383, -0.72556272,  1.38127743, -0.63943864,
#         -0.79013171, -0.79607014, -1.20511329, -0.25962894, -0.17387565,
#         -0.5298852 , -0.52504733, -0.71102597,  1.83551265, -1.1059698 ,
#          1.94458183, -0.56297505, -0.99053183,  0.99053183,  0.43991649,
#         -0.43991649,  1.38171215, -0.88565976, -0.52592737]])

# %% [markdown]
# #### It is recommended practice of splitting data in training and testing before using it in model, in our case we are keeping 80/20 data for training and testing respectively.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=72)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (5634, 29) (5634,)
# Test set: (1409, 29) (1409,)

# %% [markdown]
# #### Before fitting data to our model, feature selection is very essential part of model development.
# #### Here we are using sklearn's RandomForestClassifier with ensemble learning to choose most relevent features for our model. It will iteratively select most relevent features and eliminate least relevent features and threshold will be median for feature selection.

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

select = SelectFromModel(RandomForestClassifier(n_estimators=100, random_state=37), threshold='median')
select.fit(X_train, y_train)

X_train_s = select.transform(X_train)

print('The shape of x_train: ',X_train.shape)
print('The shape of x_train_s: ',X_train_s.shape)
# Out:
# The shape of x_train:  (5634, 29)
# The shape of x_train_s:  (5634, 15)

# %% [markdown]
# #### As we can see in above feature selection process, we got 15 most relevent features out of 29 from our training data.
# #### We can see here black colored area shows all those features are relevent and selected.

# %%
mask=select.get_support()
plt.matshow(mask.reshape(1,-1), cmap='gray_r')
plt.xlabel('Index of features')
# Out:
# Text(0.5, 0, 'Index of features')

# %% [markdown]
# #### We're fitting our training data to LogicalRegression and making prediction on our test data.
# #### Accuracy of our model is around 79%, and that means 79/100 times we can make correct prediction.

# %%
X_test_s = select.transform(X_test)

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
score = lr.fit(X_train_s,y_train).score(X_test_s, y_test)
print('The score of Logistic Regerssion for customer churn: {:.3f}'.format(score))
# Out:
# The score of Logistic Regerssion for customer churn: 0.796

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %%
X_train_s1=tf.expand_dims(X_train_s, axis=-1)

# %%
print(X_train_s1)
# Out:
# tf.Tensor(
# [[[ 0.92172746]
#   [-0.96662231]
#   [-0.65401193]
#   ...
#   [ 0.90418382]
#   [-0.56297505]
#   [ 1.12910177]]
#
#  [[ 0.03590507]
#   [-0.96662231]
#   [-0.65401193]
#   ...
#   [ 0.90418382]
#   [-0.56297505]
#   [-0.88565976]]
#
#  [[ 0.87254243]
#   [ 1.03453023]
#   [-0.65401193]
#   ...
#   [ 0.90418382]
#   [-0.56297505]
#   [ 1.12910177]]
#
#  ...
#
#  [[ 0.80909374]
#   [-0.96662231]
#   [-0.65401193]
#   ...
#   [-1.1059698 ]
#   [-0.56297505]
#   [ 1.12910177]]
#
#  [[ 1.17355481]
#   [-0.96662231]
#   [-0.65401193]
#   ...
#   [ 0.90418382]
#   [-0.56297505]
#   [-0.88565976]]
#
#  [[ 0.51496726]
#   [-0.96662231]
#   [-0.65401193]
#   ...
#   [-1.1059698 ]
#   [-0.56297505]
#   [ 1.12910177]]], shape=(5634, 15, 1), dtype=float64)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
from tensorflow.keras.optimizers import RMSprop

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(15, activation="relu", input_dim = 15),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(20, activation="relu"),
  
  tf.keras.layers.Dense(1,activation="sigmoid"),
])

model.compile(loss='binary_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

# %%
history = model.fit(X_train_s,y_train, epochs=500,batch_size=100, validation_data=(X_test_s, y_test))
# Out:
# Train on 5634 samples, validate on 1409 samples
# Epoch 1/500
# 5634/5634 [==============================] - 1s 133us/sample - loss: 0.3076 - accuracy: 0.8506 - val_loss: 0.5523 - val_accuracy: 0.7715
# Epoch 2/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.3076 - accuracy: 0.8529 - val_loss: 0.5583 - val_accuracy: 0.7672
# Epoch 3/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.3078 - accuracy: 0.8521 - val_loss: 0.5572 - val_accuracy: 0.7679
# Epoch 4/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.3090 - accuracy: 0.8506 - val_loss: 0.5550 - val_accuracy: 0.7665
# Epoch 5/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.3078 - accuracy: 0.8536 - val_loss: 0.5502 - val_accuracy: 0.7679
# Epoch 6/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.3060 - accuracy: 0.8525 - val_loss: 0.5539 - val_accuracy: 0.7700
# Epoch 7/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.3074 - accuracy: 0.8513 - val_loss: 0.5491 - val_accuracy: 0.7693
# Epoch 8/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.3078 - accuracy: 0.8525 - val_loss: 0.5525 - val_accuracy: 0.7715
# Epoch 9/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.3076 - accuracy: 0.8511 - val_loss: 0.5519 - val_accuracy: 0.7729
# Epoch 10/500
# 5634/5634 [==============================] - 1s 136us/sample - loss: 0.3057 - accuracy: 0.8541 - val_loss: 0.5533 - val_accuracy: 0.7665
# Epoch 11/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.3054 - accuracy: 0.8495 - val_loss: 0.5587 - val_accuracy: 0.7743
# Epoch 12/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.3064 - accuracy: 0.8513 - val_loss: 0.5582 - val_accuracy: 0.7715
# Epoch 13/500
# 5634/5634 [==============================] - 1s 125us/sample - loss: 0.3076 - accuracy: 0.8523 - val_loss: 0.5617 - val_accuracy: 0.7722
# Epoch 14/500
# 5634/5634 [==============================] - 1s 125us/sample - loss: 0.3092 - accuracy: 0.8493 - val_loss: 0.5537 - val_accuracy: 0.7686
# Epoch 15/500
# 5634/5634 [==============================] - 1s 119us/sample - loss: 0.3050 - accuracy: 0.8537 - val_loss: 0.5516 - val_accuracy: 0.7672
# Epoch 16/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.3062 - accuracy: 0.8530 - val_loss: 0.5652 - val_accuracy: 0.7644
# Epoch 17/500
# 5634/5634 [==============================] - 1s 123us/sample - loss: 0.3045 - accuracy: 0.8511 - val_loss: 0.5590 - val_accuracy: 0.7750
# Epoch 18/500
# 5634/5634 [==============================] - 1s 124us/sample - loss: 0.3059 - accuracy: 0.8504 - val_loss: 0.5621 - val_accuracy: 0.7679
# Epoch 19/500
# 5634/5634 [==============================] - 1s 121us/sample - loss: 0.3055 - accuracy: 0.8513 - val_loss: 0.5572 - val_accuracy: 0.7665
# Epoch 20/500
# 5634/5634 [==============================] - 1s 118us/sample - loss: 0.3048 - accuracy: 0.8520 - val_loss: 0.5562 - val_accuracy: 0.7750
# Epoch 21/500
# 5634/5634 [==============================] - 1s 132us/sample - loss: 0.3031 - accuracy: 0.8539 - val_loss: 0.5648 - val_accuracy: 0.7651
# Epoch 22/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.3036 - accuracy: 0.8527 - val_loss: 0.5591 - val_accuracy: 0.7708
# Epoch 23/500
# 5634/5634 [==============================] - 1s 109us/sample - loss: 0.3049 - accuracy: 0.8521 - val_loss: 0.5643 - val_accuracy: 0.7658
# Epoch 24/500
# 5634/5634 [==============================] - 0s 88us/sample - loss: 0.3036 - accuracy: 0.8532 - val_loss: 0.5628 - val_accuracy: 0.7686
# Epoch 25/500
# 5634/5634 [==============================] - 1s 132us/sample - loss: 0.3045 - accuracy: 0.8530 - val_loss: 0.5641 - val_accuracy: 0.7750
# Epoch 26/500
# 5634/5634 [==============================] - 1s 90us/sample - loss: 0.3041 - accuracy: 0.8500 - val_loss: 0.5656 - val_accuracy: 0.7630
# Epoch 27/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.3023 - accuracy: 0.8527 - val_loss: 0.5631 - val_accuracy: 0.7693
# Epoch 28/500
# 5634/5634 [==============================] - 1s 105us/sample - loss: 0.3035 - accuracy: 0.8553 - val_loss: 0.5655 - val_accuracy: 0.7693
# Epoch 29/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.3010 - accuracy: 0.8537 - val_loss: 0.5715 - val_accuracy: 0.7630
# Epoch 30/500
# 5634/5634 [==============================] - 1s 106us/sample - loss: 0.3019 - accuracy: 0.8543 - val_loss: 0.5719 - val_accuracy: 0.7637
# Epoch 31/500
# 5634/5634 [==============================] - 0s 88us/sample - loss: 0.3010 - accuracy: 0.8559 - val_loss: 0.5652 - val_accuracy: 0.7700
# Epoch 32/500
# 5634/5634 [==============================] - 0s 58us/sample - loss: 0.3014 - accuracy: 0.8530 - val_loss: 0.5663 - val_accuracy: 0.7764
# Epoch 33/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.3023 - accuracy: 0.8552 - val_loss: 0.5731 - val_accuracy: 0.7708
# Epoch 34/500
# 5634/5634 [==============================] - 0s 55us/sample - loss: 0.3020 - accuracy: 0.8516 - val_loss: 0.5668 - val_accuracy: 0.7672
# Epoch 35/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.3010 - accuracy: 0.8537 - val_loss: 0.5717 - val_accuracy: 0.7658
# Epoch 36/500
# 5634/5634 [==============================] - 1s 119us/sample - loss: 0.3005 - accuracy: 0.8575 - val_loss: 0.5754 - val_accuracy: 0.7615
# Epoch 37/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.3002 - accuracy: 0.8552 - val_loss: 0.5670 - val_accuracy: 0.7693
# Epoch 38/500
# 5634/5634 [==============================] - 1s 133us/sample - loss: 0.3010 - accuracy: 0.8589 - val_loss: 0.5686 - val_accuracy: 0.7644
# Epoch 39/500
# 5634/5634 [==============================] - 1s 98us/sample - loss: 0.2988 - accuracy: 0.8559 - val_loss: 0.5752 - val_accuracy: 0.7672
# Epoch 40/500
# 5634/5634 [==============================] - 1s 149us/sample - loss: 0.2997 - accuracy: 0.8571 - val_loss: 0.5678 - val_accuracy: 0.7672
# Epoch 41/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2995 - accuracy: 0.8561 - val_loss: 0.5730 - val_accuracy: 0.7637
# Epoch 42/500
# 5634/5634 [==============================] - 1s 160us/sample - loss: 0.2979 - accuracy: 0.8564 - val_loss: 0.5758 - val_accuracy: 0.7644
# Epoch 43/500
# 5634/5634 [==============================] - 1s 172us/sample - loss: 0.2973 - accuracy: 0.8561 - val_loss: 0.5783 - val_accuracy: 0.7700
# Epoch 44/500
# 5634/5634 [==============================] - 1s 149us/sample - loss: 0.2981 - accuracy: 0.8568 - val_loss: 0.5842 - val_accuracy: 0.7672
# Epoch 45/500
# 5634/5634 [==============================] - 1s 143us/sample - loss: 0.2993 - accuracy: 0.8576 - val_loss: 0.5738 - val_accuracy: 0.7587
# Epoch 46/500
# 5634/5634 [==============================] - 1s 193us/sample - loss: 0.2977 - accuracy: 0.8578 - val_loss: 0.5780 - val_accuracy: 0.7637
# Epoch 47/500
# 5634/5634 [==============================] - 1s 107us/sample - loss: 0.2988 - accuracy: 0.8543 - val_loss: 0.5784 - val_accuracy: 0.7601
# Epoch 48/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2990 - accuracy: 0.8561 - val_loss: 0.5783 - val_accuracy: 0.7686
# Epoch 49/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2979 - accuracy: 0.8552 - val_loss: 0.5816 - val_accuracy: 0.7722
# Epoch 50/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2973 - accuracy: 0.8587 - val_loss: 0.5797 - val_accuracy: 0.7630
# Epoch 51/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2968 - accuracy: 0.8564 - val_loss: 0.5873 - val_accuracy: 0.7601
# Epoch 52/500
# 5634/5634 [==============================] - 1s 105us/sample - loss: 0.2968 - accuracy: 0.8568 - val_loss: 0.5816 - val_accuracy: 0.7715
# Epoch 53/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2970 - accuracy: 0.8548 - val_loss: 0.5798 - val_accuracy: 0.7665
# Epoch 54/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.2951 - accuracy: 0.8582 - val_loss: 0.5912 - val_accuracy: 0.7615
# Epoch 55/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2949 - accuracy: 0.8594 - val_loss: 0.5870 - val_accuracy: 0.7637
# Epoch 56/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2964 - accuracy: 0.8591 - val_loss: 0.5833 - val_accuracy: 0.7622
# Epoch 57/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2957 - accuracy: 0.8592 - val_loss: 0.5890 - val_accuracy: 0.7700
# Epoch 58/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2946 - accuracy: 0.8553 - val_loss: 0.5846 - val_accuracy: 0.7622
# Epoch 59/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2967 - accuracy: 0.8587 - val_loss: 0.5890 - val_accuracy: 0.7658
# Epoch 60/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2941 - accuracy: 0.8598 - val_loss: 0.5804 - val_accuracy: 0.7637
# Epoch 61/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2944 - accuracy: 0.8585 - val_loss: 0.5822 - val_accuracy: 0.7637
# Epoch 62/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2948 - accuracy: 0.8587 - val_loss: 0.5881 - val_accuracy: 0.7658
# Epoch 63/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2938 - accuracy: 0.8591 - val_loss: 0.5911 - val_accuracy: 0.7615
# Epoch 64/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2941 - accuracy: 0.8594 - val_loss: 0.5890 - val_accuracy: 0.7672
# Epoch 65/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2956 - accuracy: 0.8619 - val_loss: 0.5880 - val_accuracy: 0.7644
# Epoch 66/500
# 5634/5634 [==============================] - 1s 111us/sample - loss: 0.2948 - accuracy: 0.8592 - val_loss: 0.5867 - val_accuracy: 0.7622
# Epoch 67/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2942 - accuracy: 0.8623 - val_loss: 0.5938 - val_accuracy: 0.7679
# Epoch 68/500
# 5634/5634 [==============================] - 1s 105us/sample - loss: 0.2936 - accuracy: 0.8603 - val_loss: 0.5876 - val_accuracy: 0.7622
# Epoch 69/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2928 - accuracy: 0.8605 - val_loss: 0.5970 - val_accuracy: 0.7637
# Epoch 70/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2952 - accuracy: 0.8578 - val_loss: 0.5905 - val_accuracy: 0.7615
# Epoch 71/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.2931 - accuracy: 0.8614 - val_loss: 0.5933 - val_accuracy: 0.7665
# Epoch 72/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2930 - accuracy: 0.8610 - val_loss: 0.5989 - val_accuracy: 0.7622
# Epoch 73/500
# 5634/5634 [==============================] - 1s 111us/sample - loss: 0.2934 - accuracy: 0.8608 - val_loss: 0.5944 - val_accuracy: 0.7651
# Epoch 74/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2921 - accuracy: 0.8587 - val_loss: 0.5899 - val_accuracy: 0.7601
# Epoch 75/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2908 - accuracy: 0.8619 - val_loss: 0.5868 - val_accuracy: 0.7608
# Epoch 76/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2921 - accuracy: 0.8591 - val_loss: 0.6056 - val_accuracy: 0.7651
# Epoch 77/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2900 - accuracy: 0.8624 - val_loss: 0.5951 - val_accuracy: 0.7700
# Epoch 78/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2910 - accuracy: 0.8592 - val_loss: 0.5978 - val_accuracy: 0.7672
# Epoch 79/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2912 - accuracy: 0.8619 - val_loss: 0.6092 - val_accuracy: 0.7644
# Epoch 80/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2936 - accuracy: 0.8600 - val_loss: 0.6004 - val_accuracy: 0.7679
# Epoch 81/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2896 - accuracy: 0.8612 - val_loss: 0.6069 - val_accuracy: 0.7672
# Epoch 82/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2904 - accuracy: 0.8601 - val_loss: 0.5991 - val_accuracy: 0.7651
# Epoch 83/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2913 - accuracy: 0.8603 - val_loss: 0.5974 - val_accuracy: 0.7708
# Epoch 84/500
# 5634/5634 [==============================] - 0s 81us/sample - loss: 0.2895 - accuracy: 0.8616 - val_loss: 0.5959 - val_accuracy: 0.7665
# Epoch 85/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2884 - accuracy: 0.8610 - val_loss: 0.6035 - val_accuracy: 0.7651
# Epoch 86/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2901 - accuracy: 0.8605 - val_loss: 0.6059 - val_accuracy: 0.7615
# Epoch 87/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2876 - accuracy: 0.8639 - val_loss: 0.6149 - val_accuracy: 0.7651
# Epoch 88/500
# 5634/5634 [==============================] - 0s 82us/sample - loss: 0.2882 - accuracy: 0.8623 - val_loss: 0.6036 - val_accuracy: 0.7630
# Epoch 89/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2900 - accuracy: 0.8598 - val_loss: 0.6091 - val_accuracy: 0.7658
# Epoch 90/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2890 - accuracy: 0.8612 - val_loss: 0.6065 - val_accuracy: 0.7658
# Epoch 91/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2882 - accuracy: 0.8605 - val_loss: 0.6045 - val_accuracy: 0.7658
# Epoch 92/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2887 - accuracy: 0.8598 - val_loss: 0.6084 - val_accuracy: 0.7637
# Epoch 93/500
# 5634/5634 [==============================] - 1s 106us/sample - loss: 0.2897 - accuracy: 0.8608 - val_loss: 0.6116 - val_accuracy: 0.7630
# Epoch 94/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2873 - accuracy: 0.8624 - val_loss: 0.6144 - val_accuracy: 0.7601
# Epoch 95/500
# 5634/5634 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.86 - 1s 106us/sample - loss: 0.2879 - accuracy: 0.8617 - val_loss: 0.6190 - val_accuracy: 0.7672
# Epoch 96/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2881 - accuracy: 0.8607 - val_loss: 0.6095 - val_accuracy: 0.7630
# Epoch 97/500
# 5634/5634 [==============================] - 1s 105us/sample - loss: 0.2861 - accuracy: 0.8607 - val_loss: 0.6164 - val_accuracy: 0.7672
# Epoch 98/500
# 5634/5634 [==============================] - 1s 119us/sample - loss: 0.2888 - accuracy: 0.8621 - val_loss: 0.6101 - val_accuracy: 0.7679
# Epoch 99/500
# 5634/5634 [==============================] - 1s 125us/sample - loss: 0.2878 - accuracy: 0.8619 - val_loss: 0.6114 - val_accuracy: 0.7587
# Epoch 100/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2869 - accuracy: 0.8649 - val_loss: 0.6172 - val_accuracy: 0.7715
# Epoch 101/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2880 - accuracy: 0.8600 - val_loss: 0.6026 - val_accuracy: 0.7637
# Epoch 102/500
# 5634/5634 [==============================] - 1s 111us/sample - loss: 0.2860 - accuracy: 0.8640 - val_loss: 0.6156 - val_accuracy: 0.7580
# Epoch 103/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2858 - accuracy: 0.8640 - val_loss: 0.6127 - val_accuracy: 0.7615
# Epoch 104/500
# 5634/5634 [==============================] - 1s 128us/sample - loss: 0.2862 - accuracy: 0.8612 - val_loss: 0.6203 - val_accuracy: 0.7722
# Epoch 105/500
# 5634/5634 [==============================] - 1s 105us/sample - loss: 0.2844 - accuracy: 0.8640 - val_loss: 0.6186 - val_accuracy: 0.7622
# Epoch 106/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2863 - accuracy: 0.8637 - val_loss: 0.6113 - val_accuracy: 0.7658
# Epoch 107/500
# 5634/5634 [==============================] - 1s 153us/sample - loss: 0.2863 - accuracy: 0.8640 - val_loss: 0.6228 - val_accuracy: 0.7615
# Epoch 108/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2850 - accuracy: 0.8623 - val_loss: 0.6201 - val_accuracy: 0.7637
# Epoch 109/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2850 - accuracy: 0.8658 - val_loss: 0.6201 - val_accuracy: 0.7637
# Epoch 110/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2845 - accuracy: 0.8632 - val_loss: 0.6209 - val_accuracy: 0.7559
# Epoch 111/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2849 - accuracy: 0.8646 - val_loss: 0.6200 - val_accuracy: 0.7566
# Epoch 112/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2858 - accuracy: 0.8632 - val_loss: 0.6261 - val_accuracy: 0.7651
# Epoch 113/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2837 - accuracy: 0.8658 - val_loss: 0.6299 - val_accuracy: 0.7672
# Epoch 114/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2866 - accuracy: 0.8649 - val_loss: 0.6265 - val_accuracy: 0.7615
# Epoch 115/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2841 - accuracy: 0.8639 - val_loss: 0.6307 - val_accuracy: 0.7601
# Epoch 116/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2844 - accuracy: 0.8655 - val_loss: 0.6254 - val_accuracy: 0.7622
# Epoch 117/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2824 - accuracy: 0.8667 - val_loss: 0.6288 - val_accuracy: 0.7615
# Epoch 118/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2825 - accuracy: 0.8663 - val_loss: 0.6371 - val_accuracy: 0.7488
# Epoch 119/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2841 - accuracy: 0.8635 - val_loss: 0.6302 - val_accuracy: 0.7651
# Epoch 120/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2865 - accuracy: 0.8626 - val_loss: 0.6256 - val_accuracy: 0.7594
# Epoch 121/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2837 - accuracy: 0.8651 - val_loss: 0.6226 - val_accuracy: 0.7615
# Epoch 122/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2822 - accuracy: 0.8692 - val_loss: 0.6289 - val_accuracy: 0.7566
# Epoch 123/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2834 - accuracy: 0.8681 - val_loss: 0.6333 - val_accuracy: 0.7601
# Epoch 124/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2824 - accuracy: 0.8647 - val_loss: 0.6285 - val_accuracy: 0.7615
# Epoch 125/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2827 - accuracy: 0.8679 - val_loss: 0.6346 - val_accuracy: 0.7665
# Epoch 126/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2810 - accuracy: 0.8635 - val_loss: 0.6341 - val_accuracy: 0.7665
# Epoch 127/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2817 - accuracy: 0.8669 - val_loss: 0.6298 - val_accuracy: 0.7729
# Epoch 128/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2836 - accuracy: 0.8639 - val_loss: 0.6294 - val_accuracy: 0.7601
# Epoch 129/500
# 5634/5634 [==============================] - 1s 113us/sample - loss: 0.2818 - accuracy: 0.8658 - val_loss: 0.6351 - val_accuracy: 0.7644
# Epoch 130/500
# 5634/5634 [==============================] - 1s 110us/sample - loss: 0.2829 - accuracy: 0.8632 - val_loss: 0.6312 - val_accuracy: 0.7672
# Epoch 131/500
# 5634/5634 [==============================] - 1s 122us/sample - loss: 0.2809 - accuracy: 0.8646 - val_loss: 0.6401 - val_accuracy: 0.7672
# Epoch 132/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2801 - accuracy: 0.8663 - val_loss: 0.6351 - val_accuracy: 0.7615
# Epoch 133/500
# 5634/5634 [==============================] - 1s 111us/sample - loss: 0.2816 - accuracy: 0.8660 - val_loss: 0.6432 - val_accuracy: 0.7665
# Epoch 134/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2817 - accuracy: 0.8663 - val_loss: 0.6363 - val_accuracy: 0.7594
# Epoch 135/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2797 - accuracy: 0.8647 - val_loss: 0.6411 - val_accuracy: 0.7580
# Epoch 136/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2803 - accuracy: 0.8671 - val_loss: 0.6438 - val_accuracy: 0.7658
# Epoch 137/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2814 - accuracy: 0.8653 - val_loss: 0.6368 - val_accuracy: 0.7644
# Epoch 138/500
# 5634/5634 [==============================] - 1s 111us/sample - loss: 0.2792 - accuracy: 0.8667 - val_loss: 0.6602 - val_accuracy: 0.7637
# Epoch 139/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.2795 - accuracy: 0.8695 - val_loss: 0.6367 - val_accuracy: 0.7594
# Epoch 140/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.2816 - accuracy: 0.8674 - val_loss: 0.6489 - val_accuracy: 0.7700
# Epoch 141/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2783 - accuracy: 0.8685 - val_loss: 0.6462 - val_accuracy: 0.7615
# Epoch 142/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2791 - accuracy: 0.8706 - val_loss: 0.6487 - val_accuracy: 0.7615
# Epoch 143/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2778 - accuracy: 0.8658 - val_loss: 0.6540 - val_accuracy: 0.7537
# Epoch 144/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2792 - accuracy: 0.8679 - val_loss: 0.6451 - val_accuracy: 0.7658
# Epoch 145/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2802 - accuracy: 0.8671 - val_loss: 0.6498 - val_accuracy: 0.7559
# Epoch 146/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2763 - accuracy: 0.8727 - val_loss: 0.6477 - val_accuracy: 0.7594
# Epoch 147/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2782 - accuracy: 0.8679 - val_loss: 0.6461 - val_accuracy: 0.7651
# Epoch 148/500
# 5634/5634 [==============================] - 0s 58us/sample - loss: 0.2764 - accuracy: 0.8653 - val_loss: 0.6622 - val_accuracy: 0.7530
# Epoch 149/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2786 - accuracy: 0.8671 - val_loss: 0.6545 - val_accuracy: 0.7637
# Epoch 150/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.2760 - accuracy: 0.8681 - val_loss: 0.6617 - val_accuracy: 0.7544
# Epoch 151/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2795 - accuracy: 0.8663 - val_loss: 0.6816 - val_accuracy: 0.7339
# Epoch 152/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2793 - accuracy: 0.8672 - val_loss: 0.6607 - val_accuracy: 0.7488
# Epoch 153/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2802 - accuracy: 0.8656 - val_loss: 0.6639 - val_accuracy: 0.7672
# Epoch 154/500
# 5634/5634 [==============================] - 1s 119us/sample - loss: 0.2788 - accuracy: 0.8663 - val_loss: 0.6595 - val_accuracy: 0.7651
# Epoch 155/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2768 - accuracy: 0.8676 - val_loss: 0.6757 - val_accuracy: 0.7509
# Epoch 156/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2777 - accuracy: 0.8699 - val_loss: 0.6537 - val_accuracy: 0.7644
# Epoch 157/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2741 - accuracy: 0.8697 - val_loss: 0.6717 - val_accuracy: 0.7516
# Epoch 158/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2777 - accuracy: 0.8688 - val_loss: 0.6635 - val_accuracy: 0.7594
# Epoch 159/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2753 - accuracy: 0.8717 - val_loss: 0.6659 - val_accuracy: 0.7488
# Epoch 160/500
# 5634/5634 [==============================] - 1s 111us/sample - loss: 0.2768 - accuracy: 0.8676 - val_loss: 0.6603 - val_accuracy: 0.7615
# Epoch 161/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2755 - accuracy: 0.8738 - val_loss: 0.6723 - val_accuracy: 0.7544
# Epoch 162/500
# 5634/5634 [==============================] - 1s 119us/sample - loss: 0.2770 - accuracy: 0.8685 - val_loss: 0.6620 - val_accuracy: 0.7594
# Epoch 163/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2808 - accuracy: 0.8676 - val_loss: 0.6685 - val_accuracy: 0.7587
# Epoch 164/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2758 - accuracy: 0.8726 - val_loss: 0.6634 - val_accuracy: 0.7523
# Epoch 165/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2757 - accuracy: 0.8676 - val_loss: 0.6609 - val_accuracy: 0.7665
# Epoch 166/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2763 - accuracy: 0.8710 - val_loss: 0.6632 - val_accuracy: 0.7573
# Epoch 167/500
# 5634/5634 [==============================] - 1s 105us/sample - loss: 0.2760 - accuracy: 0.8704 - val_loss: 0.6732 - val_accuracy: 0.7495
# Epoch 168/500
# 5634/5634 [==============================] - 1s 90us/sample - loss: 0.2748 - accuracy: 0.8710 - val_loss: 0.6770 - val_accuracy: 0.7431
# Epoch 169/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2758 - accuracy: 0.8715 - val_loss: 0.6709 - val_accuracy: 0.7630
# Epoch 170/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.2719 - accuracy: 0.8717 - val_loss: 0.6691 - val_accuracy: 0.7587
# Epoch 171/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2739 - accuracy: 0.8710 - val_loss: 0.6721 - val_accuracy: 0.7622
# Epoch 172/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2745 - accuracy: 0.8697 - val_loss: 0.6685 - val_accuracy: 0.7523
# Epoch 173/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2725 - accuracy: 0.8715 - val_loss: 0.6750 - val_accuracy: 0.7580
# Epoch 174/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2713 - accuracy: 0.8722 - val_loss: 0.6796 - val_accuracy: 0.7615
# Epoch 175/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2736 - accuracy: 0.8713 - val_loss: 0.6727 - val_accuracy: 0.7551
# Epoch 176/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2727 - accuracy: 0.8699 - val_loss: 0.6782 - val_accuracy: 0.7502
# Epoch 177/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2739 - accuracy: 0.8701 - val_loss: 0.6701 - val_accuracy: 0.7559
# Epoch 178/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2735 - accuracy: 0.8681 - val_loss: 0.6663 - val_accuracy: 0.7587
# Epoch 179/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2733 - accuracy: 0.8708 - val_loss: 0.6753 - val_accuracy: 0.7488
# Epoch 180/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2742 - accuracy: 0.8701 - val_loss: 0.6785 - val_accuracy: 0.7523
# Epoch 181/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2729 - accuracy: 0.8720 - val_loss: 0.6791 - val_accuracy: 0.7651
# Epoch 182/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2714 - accuracy: 0.8720 - val_loss: 0.6760 - val_accuracy: 0.7544
# Epoch 183/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2717 - accuracy: 0.8708 - val_loss: 0.6846 - val_accuracy: 0.7601
# Epoch 184/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2710 - accuracy: 0.8685 - val_loss: 0.6920 - val_accuracy: 0.7502
# Epoch 185/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2708 - accuracy: 0.8717 - val_loss: 0.6895 - val_accuracy: 0.7644
# Epoch 186/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2712 - accuracy: 0.8722 - val_loss: 0.6802 - val_accuracy: 0.7686
# Epoch 187/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2721 - accuracy: 0.8726 - val_loss: 0.6759 - val_accuracy: 0.7601
# Epoch 188/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2699 - accuracy: 0.8758 - val_loss: 0.6884 - val_accuracy: 0.7580
# Epoch 189/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2705 - accuracy: 0.8731 - val_loss: 0.6890 - val_accuracy: 0.7580
# Epoch 190/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2708 - accuracy: 0.8731 - val_loss: 0.6847 - val_accuracy: 0.7587
# Epoch 191/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2704 - accuracy: 0.8697 - val_loss: 0.6914 - val_accuracy: 0.7530
# Epoch 192/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2704 - accuracy: 0.8729 - val_loss: 0.6946 - val_accuracy: 0.7608
# Epoch 193/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.2700 - accuracy: 0.8722 - val_loss: 0.7001 - val_accuracy: 0.7452
# Epoch 194/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2690 - accuracy: 0.8750 - val_loss: 0.6871 - val_accuracy: 0.7630
# Epoch 195/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2700 - accuracy: 0.8718 - val_loss: 0.6899 - val_accuracy: 0.7516
# Epoch 196/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2691 - accuracy: 0.8743 - val_loss: 0.6877 - val_accuracy: 0.7622
# Epoch 197/500
# 5634/5634 [==============================] - 1s 105us/sample - loss: 0.2691 - accuracy: 0.8743 - val_loss: 0.6912 - val_accuracy: 0.7537
# Epoch 198/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2703 - accuracy: 0.8726 - val_loss: 0.6956 - val_accuracy: 0.7559
# Epoch 199/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.2689 - accuracy: 0.8743 - val_loss: 0.6970 - val_accuracy: 0.7580
# Epoch 200/500
# 5634/5634 [==============================] - 1s 105us/sample - loss: 0.2711 - accuracy: 0.8710 - val_loss: 0.6886 - val_accuracy: 0.7551
# Epoch 201/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2688 - accuracy: 0.8750 - val_loss: 0.6973 - val_accuracy: 0.7637
# Epoch 202/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2698 - accuracy: 0.8724 - val_loss: 0.6897 - val_accuracy: 0.7715
# Epoch 203/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2689 - accuracy: 0.8727 - val_loss: 0.7025 - val_accuracy: 0.7402
# Epoch 204/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2695 - accuracy: 0.8738 - val_loss: 0.6975 - val_accuracy: 0.7622
# Epoch 205/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2687 - accuracy: 0.8738 - val_loss: 0.7186 - val_accuracy: 0.7580
# Epoch 206/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2703 - accuracy: 0.8715 - val_loss: 0.7039 - val_accuracy: 0.7622
# Epoch 207/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2671 - accuracy: 0.8750 - val_loss: 0.6899 - val_accuracy: 0.7566
# Epoch 208/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2683 - accuracy: 0.8754 - val_loss: 0.6961 - val_accuracy: 0.7488
# Epoch 209/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2682 - accuracy: 0.8736 - val_loss: 0.7040 - val_accuracy: 0.7473
# Epoch 210/500
# 5634/5634 [==============================] - 1s 101us/sample - loss: 0.2703 - accuracy: 0.8736 - val_loss: 0.7044 - val_accuracy: 0.7630
# Epoch 211/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2686 - accuracy: 0.8736 - val_loss: 0.6951 - val_accuracy: 0.7637
# Epoch 212/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2670 - accuracy: 0.8724 - val_loss: 0.7105 - val_accuracy: 0.7601
# Epoch 213/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2677 - accuracy: 0.8722 - val_loss: 0.7087 - val_accuracy: 0.7644
# Epoch 214/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2685 - accuracy: 0.8752 - val_loss: 0.7020 - val_accuracy: 0.7587
# Epoch 215/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2649 - accuracy: 0.8749 - val_loss: 0.7057 - val_accuracy: 0.7566
# Epoch 216/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2668 - accuracy: 0.8759 - val_loss: 0.7168 - val_accuracy: 0.7537
# Epoch 217/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2673 - accuracy: 0.8745 - val_loss: 0.7043 - val_accuracy: 0.7573
# Epoch 218/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2669 - accuracy: 0.8772 - val_loss: 0.7127 - val_accuracy: 0.7559
# Epoch 219/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2649 - accuracy: 0.8761 - val_loss: 0.7044 - val_accuracy: 0.7622
# Epoch 220/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2668 - accuracy: 0.8740 - val_loss: 0.7258 - val_accuracy: 0.7580
# Epoch 221/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2645 - accuracy: 0.8765 - val_loss: 0.7134 - val_accuracy: 0.7495
# Epoch 222/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2659 - accuracy: 0.8763 - val_loss: 0.7102 - val_accuracy: 0.7580
# Epoch 223/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2670 - accuracy: 0.8756 - val_loss: 0.7134 - val_accuracy: 0.7566
# Epoch 224/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.2653 - accuracy: 0.8756 - val_loss: 0.7200 - val_accuracy: 0.7573
# Epoch 225/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2649 - accuracy: 0.8758 - val_loss: 0.7255 - val_accuracy: 0.7488
# Epoch 226/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2650 - accuracy: 0.8768 - val_loss: 0.7125 - val_accuracy: 0.7523
# Epoch 227/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2650 - accuracy: 0.8765 - val_loss: 0.7176 - val_accuracy: 0.7658
# Epoch 228/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2688 - accuracy: 0.8727 - val_loss: 0.7170 - val_accuracy: 0.7509
# Epoch 229/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2661 - accuracy: 0.8743 - val_loss: 0.7145 - val_accuracy: 0.7637
# Epoch 230/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2655 - accuracy: 0.8784 - val_loss: 0.7256 - val_accuracy: 0.7601
# Epoch 231/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2645 - accuracy: 0.8761 - val_loss: 0.7157 - val_accuracy: 0.7573
# Epoch 232/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2644 - accuracy: 0.8779 - val_loss: 0.7309 - val_accuracy: 0.7551
# Epoch 233/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.2651 - accuracy: 0.8754 - val_loss: 0.7233 - val_accuracy: 0.7594
# Epoch 234/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2643 - accuracy: 0.8770 - val_loss: 0.7288 - val_accuracy: 0.7587
# Epoch 235/500
# 5634/5634 [==============================] - 1s 116us/sample - loss: 0.2654 - accuracy: 0.8740 - val_loss: 0.7207 - val_accuracy: 0.7495
# Epoch 236/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2655 - accuracy: 0.8779 - val_loss: 0.7171 - val_accuracy: 0.7601
# Epoch 237/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2630 - accuracy: 0.8775 - val_loss: 0.7187 - val_accuracy: 0.7615
# Epoch 238/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2642 - accuracy: 0.8786 - val_loss: 0.7267 - val_accuracy: 0.7644
# Epoch 239/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2628 - accuracy: 0.8774 - val_loss: 0.7166 - val_accuracy: 0.7544
# Epoch 240/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2643 - accuracy: 0.8747 - val_loss: 0.7269 - val_accuracy: 0.7722
# Epoch 241/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2650 - accuracy: 0.8750 - val_loss: 0.7232 - val_accuracy: 0.7544
# Epoch 242/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2636 - accuracy: 0.8763 - val_loss: 0.7331 - val_accuracy: 0.7601
# Epoch 243/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2635 - accuracy: 0.8743 - val_loss: 0.7288 - val_accuracy: 0.7601
# Epoch 244/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2629 - accuracy: 0.8768 - val_loss: 0.7204 - val_accuracy: 0.7615
# Epoch 245/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2641 - accuracy: 0.8788 - val_loss: 0.7290 - val_accuracy: 0.7523
# Epoch 246/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2624 - accuracy: 0.8779 - val_loss: 0.7332 - val_accuracy: 0.7530
# Epoch 247/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2624 - accuracy: 0.8774 - val_loss: 0.7336 - val_accuracy: 0.7580
# Epoch 248/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2627 - accuracy: 0.8759 - val_loss: 0.7246 - val_accuracy: 0.7573
# Epoch 249/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2610 - accuracy: 0.8793 - val_loss: 0.7434 - val_accuracy: 0.7473
# Epoch 250/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2613 - accuracy: 0.8763 - val_loss: 0.7230 - val_accuracy: 0.7480
# Epoch 251/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2626 - accuracy: 0.8784 - val_loss: 0.7375 - val_accuracy: 0.7559
# Epoch 252/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2644 - accuracy: 0.8770 - val_loss: 0.7399 - val_accuracy: 0.7473
# Epoch 253/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2652 - accuracy: 0.8761 - val_loss: 0.7265 - val_accuracy: 0.7509
# Epoch 254/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2613 - accuracy: 0.8772 - val_loss: 0.7440 - val_accuracy: 0.7566
# Epoch 255/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2638 - accuracy: 0.8750 - val_loss: 0.7387 - val_accuracy: 0.7537
# Epoch 256/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2638 - accuracy: 0.8802 - val_loss: 0.7379 - val_accuracy: 0.7551
# Epoch 257/500
# 5634/5634 [==============================] - 1s 141us/sample - loss: 0.2609 - accuracy: 0.8774 - val_loss: 0.7566 - val_accuracy: 0.7551
# Epoch 258/500
# 5634/5634 [==============================] - 1s 130us/sample - loss: 0.2604 - accuracy: 0.8798 - val_loss: 0.7401 - val_accuracy: 0.7495
# Epoch 259/500
# 5634/5634 [==============================] - 1s 141us/sample - loss: 0.2616 - accuracy: 0.8793 - val_loss: 0.7417 - val_accuracy: 0.7502
# Epoch 260/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2611 - accuracy: 0.8781 - val_loss: 0.7339 - val_accuracy: 0.7644
# Epoch 261/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2623 - accuracy: 0.8765 - val_loss: 0.7400 - val_accuracy: 0.7544
# Epoch 262/500
# 5634/5634 [==============================] - 1s 130us/sample - loss: 0.2603 - accuracy: 0.8802 - val_loss: 0.7347 - val_accuracy: 0.7608
# Epoch 263/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2634 - accuracy: 0.8777 - val_loss: 0.7492 - val_accuracy: 0.7580
# Epoch 264/500
# 5634/5634 [==============================] - 1s 144us/sample - loss: 0.2640 - accuracy: 0.8781 - val_loss: 0.7461 - val_accuracy: 0.7502
# Epoch 265/500
# 5634/5634 [==============================] - 1s 155us/sample - loss: 0.2604 - accuracy: 0.8805 - val_loss: 0.7448 - val_accuracy: 0.7509
# Epoch 266/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.2615 - accuracy: 0.8777 - val_loss: 0.7523 - val_accuracy: 0.7466
# Epoch 267/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2601 - accuracy: 0.8809 - val_loss: 0.7562 - val_accuracy: 0.7601
# Epoch 268/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2611 - accuracy: 0.8770 - val_loss: 0.7493 - val_accuracy: 0.7410
# Epoch 269/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2594 - accuracy: 0.8798 - val_loss: 0.7479 - val_accuracy: 0.7516
# Epoch 270/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2584 - accuracy: 0.8809 - val_loss: 0.7500 - val_accuracy: 0.7601
# Epoch 271/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2616 - accuracy: 0.8793 - val_loss: 0.7430 - val_accuracy: 0.7509
# Epoch 272/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2582 - accuracy: 0.8837 - val_loss: 0.7420 - val_accuracy: 0.7658
# Epoch 273/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2583 - accuracy: 0.8789 - val_loss: 0.7574 - val_accuracy: 0.7431
# Epoch 274/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2587 - accuracy: 0.8779 - val_loss: 0.7552 - val_accuracy: 0.7452
# Epoch 275/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2598 - accuracy: 0.8797 - val_loss: 0.7554 - val_accuracy: 0.7516
# Epoch 276/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2599 - accuracy: 0.8811 - val_loss: 0.7502 - val_accuracy: 0.7580
# Epoch 277/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2585 - accuracy: 0.8807 - val_loss: 0.7506 - val_accuracy: 0.7530
# Epoch 278/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2587 - accuracy: 0.8782 - val_loss: 0.7420 - val_accuracy: 0.7672
# Epoch 279/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2592 - accuracy: 0.8802 - val_loss: 0.7434 - val_accuracy: 0.7495
# Epoch 280/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2599 - accuracy: 0.8775 - val_loss: 0.7546 - val_accuracy: 0.7424
# Epoch 281/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2599 - accuracy: 0.8789 - val_loss: 0.7648 - val_accuracy: 0.7537
# Epoch 282/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2612 - accuracy: 0.8765 - val_loss: 0.7569 - val_accuracy: 0.7473
# Epoch 283/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2561 - accuracy: 0.8825 - val_loss: 0.7593 - val_accuracy: 0.7530
# Epoch 284/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2586 - accuracy: 0.8795 - val_loss: 0.7477 - val_accuracy: 0.7580
# Epoch 285/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2582 - accuracy: 0.8818 - val_loss: 0.7566 - val_accuracy: 0.7523
# Epoch 286/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2570 - accuracy: 0.8821 - val_loss: 0.7510 - val_accuracy: 0.7480
# Epoch 287/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2586 - accuracy: 0.8804 - val_loss: 0.7876 - val_accuracy: 0.7367
# Epoch 288/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2636 - accuracy: 0.8758 - val_loss: 0.7483 - val_accuracy: 0.7495
# Epoch 289/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2591 - accuracy: 0.8779 - val_loss: 0.7606 - val_accuracy: 0.7473
# Epoch 290/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2560 - accuracy: 0.8805 - val_loss: 0.7616 - val_accuracy: 0.7551
# Epoch 291/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2565 - accuracy: 0.8829 - val_loss: 0.7721 - val_accuracy: 0.7480
# Epoch 292/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2595 - accuracy: 0.8800 - val_loss: 0.7471 - val_accuracy: 0.7495
# Epoch 293/500
# 5634/5634 [==============================] - 1s 90us/sample - loss: 0.2557 - accuracy: 0.8829 - val_loss: 0.7579 - val_accuracy: 0.7566
# Epoch 294/500
# 5634/5634 [==============================] - 1s 98us/sample - loss: 0.2584 - accuracy: 0.8779 - val_loss: 0.7691 - val_accuracy: 0.7473
# Epoch 295/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2564 - accuracy: 0.8834 - val_loss: 0.7667 - val_accuracy: 0.7502
# Epoch 296/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2571 - accuracy: 0.8781 - val_loss: 0.7749 - val_accuracy: 0.7488
# Epoch 297/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2589 - accuracy: 0.8784 - val_loss: 0.7735 - val_accuracy: 0.7417
# Epoch 298/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2551 - accuracy: 0.8800 - val_loss: 0.7669 - val_accuracy: 0.7566
# Epoch 299/500
# 5634/5634 [==============================] - 1s 116us/sample - loss: 0.2565 - accuracy: 0.8820 - val_loss: 0.7675 - val_accuracy: 0.7452
# Epoch 300/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.2572 - accuracy: 0.8805 - val_loss: 0.7660 - val_accuracy: 0.7445
# Epoch 301/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2536 - accuracy: 0.8834 - val_loss: 0.7664 - val_accuracy: 0.7523
# Epoch 302/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2569 - accuracy: 0.8809 - val_loss: 0.7694 - val_accuracy: 0.7530
# Epoch 303/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2559 - accuracy: 0.8800 - val_loss: 0.7651 - val_accuracy: 0.7544
# Epoch 304/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2565 - accuracy: 0.8814 - val_loss: 0.7902 - val_accuracy: 0.7395
# Epoch 305/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.2570 - accuracy: 0.8797 - val_loss: 0.7604 - val_accuracy: 0.7523
# Epoch 306/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2563 - accuracy: 0.8829 - val_loss: 0.7682 - val_accuracy: 0.7502
# Epoch 307/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2543 - accuracy: 0.8789 - val_loss: 0.7737 - val_accuracy: 0.7544
# Epoch 308/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2550 - accuracy: 0.8829 - val_loss: 0.7659 - val_accuracy: 0.7530
# Epoch 309/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2557 - accuracy: 0.8811 - val_loss: 0.7752 - val_accuracy: 0.7480
# Epoch 310/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2545 - accuracy: 0.8814 - val_loss: 0.7721 - val_accuracy: 0.7488
# Epoch 311/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2521 - accuracy: 0.8841 - val_loss: 0.7798 - val_accuracy: 0.7424
# Epoch 312/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2541 - accuracy: 0.8821 - val_loss: 0.7744 - val_accuracy: 0.7452
# Epoch 313/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2536 - accuracy: 0.8832 - val_loss: 0.7884 - val_accuracy: 0.7417
# Epoch 314/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.2545 - accuracy: 0.8777 - val_loss: 0.7798 - val_accuracy: 0.7537
# Epoch 315/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2531 - accuracy: 0.8836 - val_loss: 0.7773 - val_accuracy: 0.7466
# Epoch 316/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2539 - accuracy: 0.8830 - val_loss: 0.7768 - val_accuracy: 0.7502
# Epoch 317/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2524 - accuracy: 0.8862 - val_loss: 0.7825 - val_accuracy: 0.7473
# Epoch 318/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2530 - accuracy: 0.8816 - val_loss: 0.7730 - val_accuracy: 0.7495
# Epoch 319/500
# 5634/5634 [==============================] - 1s 122us/sample - loss: 0.2518 - accuracy: 0.8846 - val_loss: 0.7804 - val_accuracy: 0.7417
# Epoch 320/500
# ...
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2460 - accuracy: 0.8866 - val_loss: 0.8344 - val_accuracy: 0.7431
# Epoch 396/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2465 - accuracy: 0.8848 - val_loss: 0.8305 - val_accuracy: 0.7360
# Epoch 397/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2485 - accuracy: 0.8878 - val_loss: 0.8177 - val_accuracy: 0.7544
# Epoch 398/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2492 - accuracy: 0.8860 - val_loss: 0.8361 - val_accuracy: 0.7417
# Epoch 399/500
# 5634/5634 [==============================] - 1s 104us/sample - loss: 0.2454 - accuracy: 0.8860 - val_loss: 0.8406 - val_accuracy: 0.7402
# Epoch 400/500
# 5634/5634 [==============================] - 0s 77us/sample - loss: 0.2472 - accuracy: 0.8878 - val_loss: 0.8307 - val_accuracy: 0.7431
# Epoch 401/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2431 - accuracy: 0.8903 - val_loss: 0.8252 - val_accuracy: 0.7388
# Epoch 402/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2478 - accuracy: 0.8845 - val_loss: 0.8326 - val_accuracy: 0.7509
# Epoch 403/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2471 - accuracy: 0.8862 - val_loss: 0.8252 - val_accuracy: 0.7509
# Epoch 404/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2442 - accuracy: 0.8875 - val_loss: 0.8307 - val_accuracy: 0.7431
# Epoch 405/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2443 - accuracy: 0.8873 - val_loss: 0.8291 - val_accuracy: 0.7488
# Epoch 406/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2478 - accuracy: 0.8853 - val_loss: 0.8350 - val_accuracy: 0.7388
# Epoch 407/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2466 - accuracy: 0.8866 - val_loss: 0.8267 - val_accuracy: 0.7466
# Epoch 408/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2437 - accuracy: 0.8869 - val_loss: 0.8230 - val_accuracy: 0.7438
# Epoch 409/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2452 - accuracy: 0.8894 - val_loss: 0.8270 - val_accuracy: 0.7495
# Epoch 410/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2441 - accuracy: 0.8905 - val_loss: 0.8343 - val_accuracy: 0.7466
# Epoch 411/500
# 5634/5634 [==============================] - 0s 83us/sample - loss: 0.2435 - accuracy: 0.8878 - val_loss: 0.8391 - val_accuracy: 0.7310
# Epoch 412/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2431 - accuracy: 0.8860 - val_loss: 0.8284 - val_accuracy: 0.7445
# Epoch 413/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2434 - accuracy: 0.8901 - val_loss: 0.8381 - val_accuracy: 0.7466
# Epoch 414/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2475 - accuracy: 0.8845 - val_loss: 0.8261 - val_accuracy: 0.7466
# Epoch 415/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2448 - accuracy: 0.8862 - val_loss: 0.8381 - val_accuracy: 0.7402
# Epoch 416/500
# 5634/5634 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.88 - 1s 133us/sample - loss: 0.2480 - accuracy: 0.8834 - val_loss: 0.8443 - val_accuracy: 0.7360
# Epoch 417/500
# 5634/5634 [==============================] - 0s 87us/sample - loss: 0.2431 - accuracy: 0.8869 - val_loss: 0.8386 - val_accuracy: 0.7473
# Epoch 418/500
# 5634/5634 [==============================] - 1s 115us/sample - loss: 0.2433 - accuracy: 0.8885 - val_loss: 0.8415 - val_accuracy: 0.7431
# Epoch 419/500
# 5634/5634 [==============================] - 1s 130us/sample - loss: 0.2457 - accuracy: 0.8850 - val_loss: 0.8326 - val_accuracy: 0.7495
# Epoch 420/500
# 5634/5634 [==============================] - 1s 116us/sample - loss: 0.2443 - accuracy: 0.8894 - val_loss: 0.8501 - val_accuracy: 0.7495
# Epoch 421/500
# 5634/5634 [==============================] - 1s 108us/sample - loss: 0.2428 - accuracy: 0.8876 - val_loss: 0.8413 - val_accuracy: 0.7424
# Epoch 422/500
# 5634/5634 [==============================] - 1s 116us/sample - loss: 0.2443 - accuracy: 0.8827 - val_loss: 0.8435 - val_accuracy: 0.7480
# Epoch 423/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2445 - accuracy: 0.8889 - val_loss: 0.8301 - val_accuracy: 0.7530
# Epoch 424/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2438 - accuracy: 0.8875 - val_loss: 0.8418 - val_accuracy: 0.7480
# Epoch 425/500
# 5634/5634 [==============================] - 1s 116us/sample - loss: 0.2405 - accuracy: 0.8891 - val_loss: 0.8426 - val_accuracy: 0.7488
# Epoch 426/500
# 5634/5634 [==============================] - 1s 130us/sample - loss: 0.2418 - accuracy: 0.8862 - val_loss: 0.8399 - val_accuracy: 0.7480
# Epoch 427/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2424 - accuracy: 0.8898 - val_loss: 0.8476 - val_accuracy: 0.7495
# Epoch 428/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2414 - accuracy: 0.8903 - val_loss: 0.8474 - val_accuracy: 0.7410
# Epoch 429/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2425 - accuracy: 0.8871 - val_loss: 0.8432 - val_accuracy: 0.7466
# Epoch 430/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2406 - accuracy: 0.8889 - val_loss: 0.8563 - val_accuracy: 0.7459
# Epoch 431/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2434 - accuracy: 0.8892 - val_loss: 0.8497 - val_accuracy: 0.7544
# Epoch 432/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2413 - accuracy: 0.8898 - val_loss: 0.8511 - val_accuracy: 0.7410
# Epoch 433/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2421 - accuracy: 0.8891 - val_loss: 0.8499 - val_accuracy: 0.7480
# Epoch 434/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2435 - accuracy: 0.8866 - val_loss: 0.8456 - val_accuracy: 0.7502
# Epoch 435/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2444 - accuracy: 0.8853 - val_loss: 0.8508 - val_accuracy: 0.7495
# Epoch 436/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2439 - accuracy: 0.8873 - val_loss: 0.8622 - val_accuracy: 0.7438
# Epoch 437/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2439 - accuracy: 0.8878 - val_loss: 0.8677 - val_accuracy: 0.7466
# Epoch 438/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2423 - accuracy: 0.8864 - val_loss: 0.8501 - val_accuracy: 0.7402
# Epoch 439/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2436 - accuracy: 0.8887 - val_loss: 0.8597 - val_accuracy: 0.7480
# Epoch 440/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2431 - accuracy: 0.8884 - val_loss: 0.8570 - val_accuracy: 0.7381
# Epoch 441/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2443 - accuracy: 0.8852 - val_loss: 0.8727 - val_accuracy: 0.7473
# Epoch 442/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2420 - accuracy: 0.8882 - val_loss: 0.8759 - val_accuracy: 0.7417
# Epoch 443/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2404 - accuracy: 0.8894 - val_loss: 0.8522 - val_accuracy: 0.7282
# Epoch 444/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2401 - accuracy: 0.8900 - val_loss: 0.8534 - val_accuracy: 0.7395
# Epoch 445/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2431 - accuracy: 0.8892 - val_loss: 0.8676 - val_accuracy: 0.7488
# Epoch 446/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2411 - accuracy: 0.8868 - val_loss: 0.8559 - val_accuracy: 0.7516
# Epoch 447/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2440 - accuracy: 0.8855 - val_loss: 0.8619 - val_accuracy: 0.7431
# Epoch 448/500
# 5634/5634 [==============================] - 1s 119us/sample - loss: 0.2426 - accuracy: 0.8885 - val_loss: 0.8622 - val_accuracy: 0.7473
# Epoch 449/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2410 - accuracy: 0.8891 - val_loss: 0.8570 - val_accuracy: 0.7424
# Epoch 450/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2400 - accuracy: 0.8898 - val_loss: 0.8582 - val_accuracy: 0.7495
# Epoch 451/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2397 - accuracy: 0.8905 - val_loss: 0.8610 - val_accuracy: 0.7459
# Epoch 452/500
# 5634/5634 [==============================] - 1s 111us/sample - loss: 0.2430 - accuracy: 0.8889 - val_loss: 0.8478 - val_accuracy: 0.7402
# Epoch 453/500
# 5634/5634 [==============================] - 1s 119us/sample - loss: 0.2401 - accuracy: 0.8869 - val_loss: 0.8509 - val_accuracy: 0.7417
# Epoch 454/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2425 - accuracy: 0.8882 - val_loss: 0.8702 - val_accuracy: 0.7424
# Epoch 455/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2403 - accuracy: 0.8862 - val_loss: 0.8663 - val_accuracy: 0.7424
# Epoch 456/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2434 - accuracy: 0.8876 - val_loss: 0.8717 - val_accuracy: 0.7445
# Epoch 457/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2408 - accuracy: 0.8901 - val_loss: 0.8707 - val_accuracy: 0.7388
# Epoch 458/500
# 5634/5634 [==============================] - 1s 100us/sample - loss: 0.2428 - accuracy: 0.8857 - val_loss: 0.8613 - val_accuracy: 0.7466
# Epoch 459/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2409 - accuracy: 0.8889 - val_loss: 0.8761 - val_accuracy: 0.7410
# Epoch 460/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2379 - accuracy: 0.8884 - val_loss: 0.8666 - val_accuracy: 0.7417
# Epoch 461/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2388 - accuracy: 0.8898 - val_loss: 0.8674 - val_accuracy: 0.7374
# Epoch 462/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2417 - accuracy: 0.8896 - val_loss: 0.8731 - val_accuracy: 0.7495
# Epoch 463/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.2403 - accuracy: 0.8887 - val_loss: 0.8596 - val_accuracy: 0.7367
# Epoch 464/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2394 - accuracy: 0.8882 - val_loss: 0.8694 - val_accuracy: 0.7452
# Epoch 465/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2432 - accuracy: 0.8850 - val_loss: 0.8790 - val_accuracy: 0.7339
# Epoch 466/500
# 5634/5634 [==============================] - 0s 80us/sample - loss: 0.2419 - accuracy: 0.8880 - val_loss: 0.8692 - val_accuracy: 0.7480
# Epoch 467/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2393 - accuracy: 0.8885 - val_loss: 0.8834 - val_accuracy: 0.7438
# Epoch 468/500
# 5634/5634 [==============================] - 0s 67us/sample - loss: 0.2423 - accuracy: 0.8864 - val_loss: 0.8890 - val_accuracy: 0.7424
# Epoch 469/500
# 5634/5634 [==============================] - 1s 103us/sample - loss: 0.2409 - accuracy: 0.8878 - val_loss: 0.8691 - val_accuracy: 0.7417
# Epoch 470/500
# 5634/5634 [==============================] - 0s 88us/sample - loss: 0.2393 - accuracy: 0.8917 - val_loss: 0.8762 - val_accuracy: 0.7495
# Epoch 471/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2374 - accuracy: 0.8898 - val_loss: 0.8834 - val_accuracy: 0.7424
# Epoch 472/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2377 - accuracy: 0.8900 - val_loss: 0.8727 - val_accuracy: 0.7339
# Epoch 473/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2376 - accuracy: 0.8910 - val_loss: 0.8795 - val_accuracy: 0.7402
# Epoch 474/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2412 - accuracy: 0.8901 - val_loss: 0.8723 - val_accuracy: 0.7410
# Epoch 475/500
# 5634/5634 [==============================] - 1s 92us/sample - loss: 0.2394 - accuracy: 0.8917 - val_loss: 0.8784 - val_accuracy: 0.7346
# Epoch 476/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2386 - accuracy: 0.8871 - val_loss: 0.8730 - val_accuracy: 0.7438
# Epoch 477/500
# 5634/5634 [==============================] - 1s 89us/sample - loss: 0.2372 - accuracy: 0.8896 - val_loss: 0.8823 - val_accuracy: 0.7480
# Epoch 478/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2380 - accuracy: 0.8892 - val_loss: 0.8807 - val_accuracy: 0.7424
# Epoch 479/500
# 5634/5634 [==============================] - 1s 94us/sample - loss: 0.2375 - accuracy: 0.8923 - val_loss: 0.8780 - val_accuracy: 0.7417
# Epoch 480/500
# 5634/5634 [==============================] - 1s 116us/sample - loss: 0.2386 - accuracy: 0.8882 - val_loss: 0.8787 - val_accuracy: 0.7445
# Epoch 481/500
# 5634/5634 [==============================] - 1s 111us/sample - loss: 0.2397 - accuracy: 0.8880 - val_loss: 0.8728 - val_accuracy: 0.7495
# Epoch 482/500
# 5634/5634 [==============================] - 1s 122us/sample - loss: 0.2394 - accuracy: 0.8882 - val_loss: 0.8865 - val_accuracy: 0.7445
# Epoch 483/500
# 5634/5634 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.88 - 1s 122us/sample - loss: 0.2418 - accuracy: 0.8850 - val_loss: 0.8782 - val_accuracy: 0.7431
# Epoch 484/500
# 5634/5634 [==============================] - 1s 111us/sample - loss: 0.2383 - accuracy: 0.8914 - val_loss: 0.8881 - val_accuracy: 0.7480
# Epoch 485/500
# 5634/5634 [==============================] - 1s 114us/sample - loss: 0.2392 - accuracy: 0.8912 - val_loss: 0.8992 - val_accuracy: 0.7331
# Epoch 486/500
# 5634/5634 [==============================] - 1s 130us/sample - loss: 0.2366 - accuracy: 0.8916 - val_loss: 0.8874 - val_accuracy: 0.7459
# Epoch 487/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2361 - accuracy: 0.8889 - val_loss: 0.8841 - val_accuracy: 0.7445
# Epoch 488/500
# 5634/5634 [==============================] - 1s 97us/sample - loss: 0.2363 - accuracy: 0.8921 - val_loss: 0.8838 - val_accuracy: 0.7473
# Epoch 489/500
# 5634/5634 [==============================] - 0s 78us/sample - loss: 0.2363 - accuracy: 0.8903 - val_loss: 0.8875 - val_accuracy: 0.7374
# Epoch 490/500
# 5634/5634 [==============================] - 0s 86us/sample - loss: 0.2377 - accuracy: 0.8900 - val_loss: 0.8901 - val_accuracy: 0.7509
# Epoch 491/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2381 - accuracy: 0.8887 - val_loss: 0.8889 - val_accuracy: 0.7381
# Epoch 492/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2369 - accuracy: 0.8926 - val_loss: 0.8840 - val_accuracy: 0.7410
# Epoch 493/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2359 - accuracy: 0.8910 - val_loss: 0.8951 - val_accuracy: 0.7346
# Epoch 494/500
# 5634/5634 [==============================] - 0s 72us/sample - loss: 0.2381 - accuracy: 0.8882 - val_loss: 0.8844 - val_accuracy: 0.7459
# Epoch 495/500
# 5634/5634 [==============================] - 0s 61us/sample - loss: 0.2371 - accuracy: 0.8898 - val_loss: 0.8884 - val_accuracy: 0.7388
# Epoch 496/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2397 - accuracy: 0.8891 - val_loss: 0.8925 - val_accuracy: 0.7431
# Epoch 497/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2412 - accuracy: 0.8884 - val_loss: 0.8899 - val_accuracy: 0.7388
# Epoch 498/500
# 5634/5634 [==============================] - 0s 75us/sample - loss: 0.2390 - accuracy: 0.8885 - val_loss: 0.8816 - val_accuracy: 0.7395
# Epoch 499/500
# 5634/5634 [==============================] - 0s 64us/sample - loss: 0.2364 - accuracy: 0.8900 - val_loss: 0.8922 - val_accuracy: 0.7459
# Epoch 500/500
# 5634/5634 [==============================] - 0s 69us/sample - loss: 0.2379 - accuracy: 0.8901 - val_loss: 0.8924 - val_accuracy: 0.7431

# %%
y_pred = model.predict(X_test_s)

# %%
print(y_pred)
# Out:
# [[0.58592486]
#  [0.04280126]
#  [0.7233945 ]
#  ...
#  [0.03465325]
#  [0.14816129]
#  [0.1555    ]]

# %%
y_pred = (y_pred > 0.5)
print(y_pred[0:10])
# Out:
# [[ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[876, 151],
#        [173, 209]], dtype=int64)

# %%
TP = 178
TN = 919
FP = 204
FN = 108
Accuracy = (TP + TN)/(TP + TN + FN + FP)
Accuracy
# Out:
# 0.7785663591199432

# %%
Precision = TP / (TP + FP)
Precision
# Out:
# 0.46596858638743455

# %%
Recall = TP / (TP + FN)
Recall
# Out:
# 0.6223776223776224

# %%
F1_Score = 2 * Precision * Recall / (Precision + Recall)
F1_Score
# Out:
# 0.532934131736527

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
type(acc)
# Out:
# list

# %%
type
